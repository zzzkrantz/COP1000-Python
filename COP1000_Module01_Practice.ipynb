# %%
print("Hello, COP 1000!")
print("I am learning Python.")
print("This is my first Google Colab notebook.")
# Out:
# Hello, COP 1000!
# I am learning Python.
# This is my first Google Colab notebook.

# %%
print("Python is running in my browser!")
# Out:
# Python is running in my browser!

# %% [markdown]
# In part 1-6 of the google notebook assignment I was introduced primarily to the "print" command. the use of text and code cells is also demonstrated.

# %%
#this is a Python comment
print("comments help explain our code!")

# %%
print("Hello, Python!")
# Out:
# Hello, Python!
